# %%
import torch
from diffusers import StableDiffusionXLPipeline, StableDiffusionXLImg2ImgPipeline
# Out:
# F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: Could not find module 'F:\anaconda\anaconda3\envs\DeltaZero\Lib\site-packages\torchvision\image.pyd' (or one of its dependencies). Try using the full path with constructor syntax.
#   warn(f"Failed to load image Python extension: {e}")

# %%
pipe = StableDiffusionXLPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0", torch_dtype=torch.float16, variant="fp16", use_safetensors=True
)
pipe.to("cuda")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 4
#       1 pipe = StableDiffusionXLPipeline.from_pretrained(
#       2     "stabilityai/stable-diffusion-xl-base-1.0", torch_dtype=torch.float16, variant="fp16", use_safetensors=True
#       3 )
# ----> 4 pipe.to("cuda:0")
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\diffusers\pipelines\pipeline_utils.py:431, in DiffusionPipeline.to(self, *args, **kwargs)
#     427     logger.warning(
#     428         f"The module '{module.__class__.__name__}' has been loaded in 8bit and moving it to {dtype} via `.to()` is not yet supported. Module is still on {module.device}."
#     429     )
#     430 else:
# --> 431     module.to(device, dtype)
#     433 if (
#     434     module.dtype == torch.float16
#     435     and str(device) in ["cpu"]
#     436     and not silence_dtype_warnings
#     437     and not is_offloaded
#     438 ):
#     439     logger.warning(
#     440         "Pipelines loaded with `dtype=torch.float16` cannot run with `cpu` device. It"
#     441         " is not recommended to move them to `cpu` as running them will fail. Please make"
#    (...)
#     444         " `torch_dtype=torch.float16` argument, or use another device for inference."
#     445     )
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\transformers\modeling_utils.py:2883, in PreTrainedModel.to(self, *args, **kwargs)
#    2878     if dtype_present_in_args:
#    2879         raise ValueError(
#    2880             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    2881             " `dtype` by passing the correct `torch_dtype` argument."
#    2882         )
# -> 2883 return super().to(*args, **kwargs)
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\torch\nn\modules\module.py:989, in Module.to(self, *args, **kwargs)
#     985         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#     986                     non_blocking, memory_format=convert_to_format)
#     987     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# --> 989 return self._apply(convert)
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\torch\nn\modules\module.py:641, in Module._apply(self, fn)
#     639 def _apply(self, fn):
#     640     for module in self.children():
# --> 641         module._apply(fn)
#     643     def compute_should_use_set_data(tensor, tensor_applied):
#     644         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     645             # If the new tensor has compatible tensor type as the existing tensor,
#     646             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     651             # global flag to let the user control whether they want the future
#     652             # behavior of overwriting the existing tensor or not.
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\torch\nn\modules\module.py:641, in Module._apply(self, fn)
#     639 def _apply(self, fn):
#     640     for module in self.children():
# --> 641         module._apply(fn)
#     643     def compute_should_use_set_data(tensor, tensor_applied):
#     644         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     645             # If the new tensor has compatible tensor type as the existing tensor,
#     646             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     651             # global flag to let the user control whether they want the future
#     652             # behavior of overwriting the existing tensor or not.
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\torch\nn\modules\module.py:641, in Module._apply(self, fn)
#     639 def _apply(self, fn):
#     640     for module in self.children():
# --> 641         module._apply(fn)
#     643     def compute_should_use_set_data(tensor, tensor_applied):
#     644         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     645             # If the new tensor has compatible tensor type as the existing tensor,
#     646             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     651             # global flag to let the user control whether they want the future
#     652             # behavior of overwriting the existing tensor or not.
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\torch\nn\modules\module.py:664, in Module._apply(self, fn)
#     660 # Tensors stored in modules are graph leaves, and we don't want to
#     661 # track autograd history of `param_applied`, so we have to use
#     662 # `with torch.no_grad():`
#     663 with torch.no_grad():
# --> 664     param_applied = fn(param)
#     665 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     666 if should_use_set_data:
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\torch\nn\modules\module.py:987, in Module.to.<locals>.convert(t)
#     984 if convert_to_format is not None and t.dim() in (4, 5):
#     985     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#     986                 non_blocking, memory_format=convert_to_format)
# --> 987 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\torch\cuda\__init__.py:221, in _lazy_init()
#     217     raise RuntimeError(
#     218         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     219         "multiprocessing, you must use the 'spawn' start method")
#     220 if not hasattr(torch._C, '_cuda_getDeviceCount'):
# --> 221     raise AssertionError("Torch not compiled with CUDA enabled")
#     222 if _cudart is None:
#     223     raise AssertionError(
#     224         "libcudart functions unavailable. It looks like you have a broken build?")
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
prompt = "An astronaut riding a green horse"
image = pipe(prompt=prompt).images[0]
image
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 2
#       1 prompt = "An astronaut riding green horse"
# ----> 2 image = pipe(prompt=prompt).images[0]
#       3 image
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\diffusers\pipelines\stable_diffusion_xl\pipeline_stable_diffusion_xl.py:1077, in StableDiffusionXLPipeline.__call__(self, prompt, prompt_2, height, width, num_inference_steps, timesteps, sigmas, denoising_end, guidance_scale, negative_prompt, negative_prompt_2, num_images_per_prompt, eta, generator, latents, prompt_embeds, negative_prompt_embeds, pooled_prompt_embeds, negative_pooled_prompt_embeds, ip_adapter_image, ip_adapter_image_embeds, output_type, return_dict, cross_attention_kwargs, guidance_rescale, original_size, crops_coords_top_left, target_size, negative_original_size, negative_crops_coords_top_left, negative_target_size, clip_skip, callback_on_step_end, callback_on_step_end_tensor_inputs, **kwargs)
#    1067 # 3. Encode input prompt
#    1068 lora_scale = (
#    1069     self.cross_attention_kwargs.get("scale", None) if self.cross_attention_kwargs is not None else None
#    1070 )
#    1072 (
#    1073     prompt_embeds,
#    1074     negative_prompt_embeds,
#    1075     pooled_prompt_embeds,
#    1076     negative_pooled_prompt_embeds,
# -> 1077 ) = self.encode_prompt(
#    1078     prompt=prompt,
#    1079     prompt_2=prompt_2,
#    1080     device=device,
#    1081     num_images_per_prompt=num_images_per_prompt,
#    1082     do_classifier_free_guidance=self.do_classifier_free_guidance,
#    1083     negative_prompt=negative_prompt,
#    1084     negative_prompt_2=negative_prompt_2,
#    1085     prompt_embeds=prompt_embeds,
#    1086     negative_prompt_embeds=negative_prompt_embeds,
#    1087     pooled_prompt_embeds=pooled_prompt_embeds,
#    1088     negative_pooled_prompt_embeds=negative_pooled_prompt_embeds,
#    1089     lora_scale=lora_scale,
#    1090     clip_skip=self.clip_skip,
#    1091 )
#    1093 # 4. Prepare timesteps
#    1094 timesteps, num_inference_steps = retrieve_timesteps(
#    1095     self.scheduler, num_inference_steps, device, timesteps, sigmas
#    1096 )
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\diffusers\pipelines\stable_diffusion_xl\pipeline_stable_diffusion_xl.py:397, in StableDiffusionXLPipeline.encode_prompt(self, prompt, prompt_2, device, num_images_per_prompt, do_classifier_free_guidance, negative_prompt, negative_prompt_2, prompt_embeds, negative_prompt_embeds, pooled_prompt_embeds, negative_pooled_prompt_embeds, lora_scale, clip_skip)
#     391     removed_text = tokenizer.batch_decode(untruncated_ids[:, tokenizer.model_max_length - 1 : -1])
#     392     logger.warning(
#     393         "The following part of your input was truncated because CLIP can only handle sequences up to"
#     394         f" {tokenizer.model_max_length} tokens: {removed_text}"
#     395     )
# --> 397 prompt_embeds = text_encoder(text_input_ids.to(device), output_hidden_states=True)
#     399 # We are only ALWAYS interested in the pooled output of the final text encoder
#     400 pooled_prompt_embeds = prompt_embeds[0]
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\transformers\models\clip\modeling_clip.py:986, in CLIPTextModel.forward(self, input_ids, attention_mask, position_ids, output_attentions, output_hidden_states, return_dict)
#     967 r"""
#     968 Returns:
#     969
#    (...)
#     982 >>> pooled_output = outputs.pooler_output  # pooled (EOS token) states
#     983 ```"""
#     984 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 986 return self.text_model(
#     987     input_ids=input_ids,
#     988     attention_mask=attention_mask,
#     989     position_ids=position_ids,
#     990     output_attentions=output_attentions,
#     991     output_hidden_states=output_hidden_states,
#     992     return_dict=return_dict,
#     993 )
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\transformers\models\clip\modeling_clip.py:890, in CLIPTextTransformer.forward(self, input_ids, attention_mask, position_ids, output_attentions, output_hidden_states, return_dict)
#     886 if attention_mask is not None and not self._use_flash_attention_2:
#     887     # [bsz, seq_len] -> [bsz, 1, tgt_seq_len, src_seq_len]
#     888     attention_mask = _prepare_4d_attention_mask(attention_mask, hidden_states.dtype)
# --> 890 encoder_outputs = self.encoder(
#     891     inputs_embeds=hidden_states,
#     892     attention_mask=attention_mask,
#     893     causal_attention_mask=causal_attention_mask,
#     894     output_attentions=output_attentions,
#     895     output_hidden_states=output_hidden_states,
#     896     return_dict=return_dict,
#     897 )
#     899 last_hidden_state = encoder_outputs[0]
#     900 last_hidden_state = self.final_layer_norm(last_hidden_state)
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\transformers\models\clip\modeling_clip.py:813, in CLIPEncoder.forward(self, inputs_embeds, attention_mask, causal_attention_mask, output_attentions, output_hidden_states, return_dict)
#     805     layer_outputs = self._gradient_checkpointing_func(
#     806         encoder_layer.__call__,
#     807         hidden_states,
#    (...)
#     810         output_attentions,
#     811     )
#     812 else:
# --> 813     layer_outputs = encoder_layer(
#     814         hidden_states,
#     815         attention_mask,
#     816         causal_attention_mask,
#     817         output_attentions=output_attentions,
#     818     )
#     820 hidden_states = layer_outputs[0]
#     822 if output_attentions:
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\transformers\models\clip\modeling_clip.py:547, in CLIPEncoderLayer.forward(self, hidden_states, attention_mask, causal_attention_mask, output_attentions)
#     535 """
#     536 Args:
#     537     hidden_states (`torch.FloatTensor`): input to the layer of shape `(batch, seq_len, embed_dim)`
#    (...)
#     543         returned tensors for more detail.
#     544 """
#     545 residual = hidden_states
# --> 547 hidden_states = self.layer_norm1(hidden_states)
#     548 hidden_states, attn_weights = self.self_attn(
#     549     hidden_states=hidden_states,
#     550     attention_mask=attention_mask,
#     551     causal_attention_mask=causal_attention_mask,
#     552     output_attentions=output_attentions,
#     553 )
#     554 hidden_states = residual + hidden_states
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\torch\nn\modules\normalization.py:190, in LayerNorm.forward(self, input)
#     189 def forward(self, input: Tensor) -> Tensor:
# --> 190     return F.layer_norm(
#     191         input, self.normalized_shape, self.weight, self.bias, self.eps)
#
# File F:\anaconda\anaconda3\envs\DeltaZero\lib\site-packages\torch\nn\functional.py:2515, in layer_norm(input, normalized_shape, weight, bias, eps)
#    2511 if has_torch_function_variadic(input, weight, bias):
#    2512     return handle_torch_function(
#    2513         layer_norm, (input, weight, bias), input, normalized_shape, weight=weight, bias=bias, eps=eps
#    2514     )
# -> 2515 return torch.layer_norm(input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled)
#
# RuntimeError: "LayerNormKernelImpl" not implemented for 'Half'

# %%
prompt = "An astronaut riding a green horse"
image = pipe(prompt=prompt).images[0]
image
